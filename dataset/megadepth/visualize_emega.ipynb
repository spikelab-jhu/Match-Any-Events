# %%
import torch
import h5py
import numpy as np

import matplotlib.pyplot as plt

visualize_path = '/media/rex/rex_4t_2/data/megadepth/event_megadepth/e_mega/0240/images/2371598684_2c7853a75c_o.h5'

# %%
with h5py.File(visualize_path) as f:
    print(f.keys())

    event = f['event'][:]
    image = f['image'][:]
# Out:
# <KeysViewHDF5 ['K', 'depth', 'event', 'image', 'pose']>

# %%
event.shape
# Out:
# (20, 360, 640)

# %%
fig, axes = plt.subplots(8, 2, figsize=(8, 32))

for i, ax in enumerate(axes.flat):
    ax.imshow(event[i], cmap="gray")
    ax.set_title(f"Img {i}")
    ax.axis("off")

plt.tight_layout()
plt.show()

plt.figure()
plt.imshow(image, cmap='gray')
plt.show()
